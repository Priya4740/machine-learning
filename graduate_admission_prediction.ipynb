# %% [markdown]
# <a href="https://colab.research.google.com/github/Priya4740/machine-learning/blob/main/graduate_admission_prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("https://raw.githubusercontent.com/bapujik/dataSets/refs/heads/main/GAdata.csv")

# %%
data
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# 0             1        337          118                  4  4.5  4.5  9.65
# 1             2        324          107                  4  4.0  4.5  8.87
# 2             3        316          104                  3  3.0  3.5  8.00
# 3             4        322          110                  3  3.5  2.5  8.67
# 4             5        314          103                  2  2.0  3.0  8.21
# ..          ...        ...          ...                ...  ...  ...   ...
# 495         496        332          108                  5  4.5  4.0  9.02
# 496         497        337          117                  5  5.0  5.0  9.87
# 497         498        330          120                  5  4.5  5.0  9.56
# 498         499        312          103                  4  4.0  5.0  8.43
# 499         500        327          113                  4  4.5  4.5  9.04
#
#      Research  Chance of Admit
# 0           1             0.92
# ...

# %%
data.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# 0           1        337          118                  4  4.5  4.5  9.65
# 1           2        324          107                  4  4.0  4.5  8.87
# 2           3        316          104                  3  3.0  3.5  8.00
# 3           4        322          110                  3  3.5  2.5  8.67
# 4           5        314          103                  2  2.0  3.0  8.21
#
#    Research  Chance of Admit
# 0         1             0.92
# 1         1             0.76
# 2         1             0.72
# 3         1             0.80
# 4         0             0.65

# %%
data.tail()
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# 495         496        332          108                  5  4.5  4.0  9.02
# 496         497        337          117                  5  5.0  5.0  9.87
# 497         498        330          120                  5  4.5  5.0  9.56
# 498         499        312          103                  4  4.0  5.0  8.43
# 499         500        327          113                  4  4.5  4.5  9.04
#
#      Research  Chance of Admit
# 495         1             0.87
# 496         1             0.96
# 497         1             0.93
# 498         0             0.73
# 499         0             0.84

# %%
data['GRE Score'].mean()
# Out:
# np.float64(316.472)

# %% [markdown]
# used to find n unique colums in

# %%
data.nunique()
# Out:
# Serial No.           500
# GRE Score             49
# TOEFL Score           29
# University Rating      5
# SOP                    9
# LOR                    9
# CGPA                 184
# Research               2
# Chance of Admit       61
# dtype: int64

# %%
data['Research']
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 495    1
# 496    1
# 497    1
# 498    0
# 499    0
# Name: Research, Length: 500, dtype: int64

# %%
data['Research'].unique()
# Out:
# array([1, 0])

# %%
data['University Rating'].unique()
# Out:
# array([4, 3, 2, 5, 1])

# %%
data['SOP'].unique()
# Out:
# array([4.5, 4. , 3. , 3.5, 2. , 5. , 1.5, 1. , 2.5])

# %%
data['LOR'].unique()
# Out:
# array([4.5, 3.5, 2.5, 3. , 4. , 1.5, 2. , 5. , 1. ])

# %%
data['CGPA'].unique()
# Out:
# array([9.65, 8.87, 8.  , 8.67, 8.21, 9.34, 8.2 , 7.9 , 8.6 , 8.4 , 9.  ,
#        9.1 , 8.3 , 8.7 , 8.8 , 8.5 , 9.5 , 9.7 , 9.8 , 9.6 , 7.5 , 7.2 ,
#        7.3 , 8.1 , 9.4 , 9.2 , 7.8 , 7.7 , 9.3 , 8.85, 7.4 , 7.6 , 6.8 ,
#        8.92, 9.02, 8.64, 9.22, 9.16, 9.64, 9.76, 9.45, 9.04, 8.9 , 8.56,
#        8.72, 8.22, 7.54, 7.36, 8.02, 9.36, 8.66, 8.42, 8.28, 8.14, 8.76,
#        7.92, 7.66, 8.03, 7.88, 7.84, 8.96, 9.24, 8.88, 8.46, 8.12, 8.25,
#        8.47, 9.05, 8.78, 9.18, 9.46, 9.38, 8.48, 8.68, 8.34, 8.45, 8.62,
#        7.46, 7.28, 8.84, 9.56, 9.48, 8.36, 9.32, 8.71, 9.35, 8.65, 9.28,
#        8.77, 8.16, 9.08, 9.12, 9.15, 9.44, 9.92, 9.11, 8.26, 9.43, 9.06,
#        8.75, 8.89, 8.69, 7.86, 9.01, 8.97, 8.33, 8.27, 7.98, 8.04, 9.07,
#        9.13, 9.23, 8.32, 8.98, 8.94, 9.53, 8.52, 8.43, 8.54, 9.91, 9.87,
#        7.65, 7.89, 9.14, 9.66, 9.78, 9.42, 9.26, 8.79, 8.23, 8.53, 8.07,
#        9.31, 9.17, 9.19, 8.37, 7.68, 8.15, 8.73, 8.83, 8.57, 9.68, 8.09,
# ...

# %%
data['LOR'].median()
# Out:
# 3.5

# %%
data['SOP'].median()
# Out:
# 3.5

# %% [markdown]
# describe gives descriptive statics of data

# %%
data.describe()
# Out:
#        Serial No.   GRE Score  TOEFL Score  University Rating         SOP  \
# count  500.000000  500.000000   500.000000         500.000000  500.000000
# mean   250.500000  316.472000   107.192000           3.114000    3.374000
# std    144.481833   11.295148     6.081868           1.143512    0.991004
# min      1.000000  290.000000    92.000000           1.000000    1.000000
# 25%    125.750000  308.000000   103.000000           2.000000    2.500000
# 50%    250.500000  317.000000   107.000000           3.000000    3.500000
# 75%    375.250000  325.000000   112.000000           4.000000    4.000000
# max    500.000000  340.000000   120.000000           5.000000    5.000000
#
#              LOR        CGPA    Research  Chance of Admit
# count  500.00000  500.000000  500.000000        500.00000
# mean     3.48400    8.576440    0.560000          0.72174
# std      0.92545    0.604813    0.496884          0.14114
# min      1.00000    6.800000    0.000000          0.34000
# ...

# %% [markdown]
# histogram checks for how many values are present in the range

# %%
plt.hist(data['GRE Score'])
# Out:
# (array([ 5., 36., 47., 50., 79., 70., 86., 63., 37., 27.]),
#  array([290., 295., 300., 305., 310., 315., 320., 325., 330., 335., 340.]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(data['Chance of Admit'])
# Out:
# (array([ 8., 16., 24., 47., 63., 78., 93., 62., 48., 61.]),
#  array([0.34 , 0.403, 0.466, 0.529, 0.592, 0.655, 0.718, 0.781, 0.844,
#         0.907, 0.97 ]),
#  <BarContainer object of 10 artists>)

# %%
data.isnull()
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating    SOP    LOR  \
# 0         False      False        False              False  False  False
# 1         False      False        False              False  False  False
# 2         False      False        False              False  False  False
# 3         False      False        False              False  False  False
# 4         False      False        False              False  False  False
# ..          ...        ...          ...                ...    ...    ...
# 495       False      False        False              False  False  False
# 496       False      False        False              False  False  False
# 497       False      False        False              False  False  False
# 498       False      False        False              False  False  False
# 499       False      False        False              False  False  False
#
#       CGPA  Research  Chance of Admit
# 0    False     False            False
# ...

# %%
data.isnull().sum()
# Out:
# Serial No.           0
# GRE Score            0
# TOEFL Score          0
# University Rating    0
# SOP                  0
# LOR                  0
# CGPA                 0
# Research             0
# Chance of Admit      0
# dtype: int64

# %% [markdown]
# outliers- THE VALUES THAT ARE BEYOND THE RANGE
# characteristics: IT CHANGES MEAN,

# %%
np.random.normal(0,1,5)
# Out:
# array([ 0.28750542,  0.248195  , -0.86540216, -0.55347223,  0.04776979])

# %%
import matplotlib.pyplot as plt
import numpy as np
np.random.seed(0) # used too generate same squence again and again
num_students=50
exam1_scores=np.random.normal(70,10,num_students)
exam2_scores=np.random.normal(75,15,num_students)

# %%
exam1_scores
# Out:
# array([87.64052346, 74.00157208, 79.78737984, 92.40893199, 88.6755799 ,
#        60.2272212 , 79.50088418, 68.48642792, 68.96781148, 74.10598502,
#        71.44043571, 84.54273507, 77.61037725, 71.21675016, 74.43863233,
#        73.33674327, 84.94079073, 67.94841736, 73.13067702, 61.45904261,
#        44.47010184, 76.53618595, 78.64436199, 62.5783498 , 92.69754624,
#        55.45634325, 70.45758517, 68.1281615 , 85.32779214, 84.6935877 ,
#        71.54947426, 73.7816252 , 61.12214252, 50.19203532, 66.52087851,
#        71.56348969, 82.30290681, 82.02379849, 66.12673183, 66.97697249,
#        59.51447035, 55.79982063, 52.93729809, 89.50775395, 64.90347818,
#        65.61925698, 57.4720464 , 77.77490356, 53.86102152, 67.8725972 ])

# %%
exam2_scores
# Out:
# array([ 61.56800158,  80.80353747,  67.33792294,  57.29051724,
#         74.57726657,  81.42497806,  75.99775834,  79.53707847,
#         65.48516859,  69.55888251,  64.91309328,  69.60670258,
#         62.80280577,  49.10576097,  77.66139213,  68.97328596,
#         50.5470248 ,  81.94173383,  61.39052453,  75.77918094,
#         85.93635843,  76.93474366,  92.09101027,  56.47761269,
#         81.03512462,  64.72784864,  61.93804276,  66.31725503,
#         70.32671202,  75.84248013,  57.52275239,  88.5123973 ,
#         81.9849366 ,  51.95634471,  97.32378291, 103.43833764,
#         92.68169357,  72.30112746,  58.93871068,  90.8167759 ,
#         68.9523458 ,  93.33667606,  78.12412467,  89.64958555,
#         80.34549596,  85.59859752,  75.15750031, 101.78805741,
#         76.90368139,  81.02984045])

# %%
exam1_scores.std()
# Out:
# np.float64(11.255229205548462)

# %%
exam1_scores.mean()
# Out:
# np.float64(71.40559272313098)

# %%
exam2_scores.std()
# Out:
# np.float64(13.006045483866448)

# %%
exam2_scores.mean()
# Out:
# np.float64(74.68585138133808)

# %%
plt.hist(exam1_scores)
# Out:
# (array([1., 3., 3., 5., 9., 8., 7., 5., 5., 4.]),
#  array([44.47010184, 49.29284628, 54.11559072, 58.93833516, 63.7610796 ,
#         68.58382404, 73.40656848, 78.22931292, 83.05205736, 87.8748018 ,
#         92.69754624]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(exam2_scores)
# Out:
# (array([ 3.,  4.,  6.,  8.,  6., 10.,  4.,  4.,  3.,  2.]),
#  array([ 49.10576097,  54.53901863,  59.9722763 ,  65.40553397,
#          70.83879164,  76.2720493 ,  81.70530697,  87.13856464,
#          92.57182231,  98.00507997, 103.43833764]),
#  <BarContainer object of 10 artists>)

# %%
plt.boxplot(exam1_scores)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7d8071333020>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7d8071333560>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7d8071332d80>],
#  'medians': [<matplotlib.lines.Line2D at 0x7d8071333b00>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7d8071333e00>],
#  'means': []}

# %%
plt.boxplot(exam2_scores)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7d80710713d0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7d8071071970>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7d8071071100>],
#  'medians': [<matplotlib.lines.Line2D at 0x7d8071071f40>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7d8071072270>],
#  'means': []}

# %%
exam1_scores.min()
# Out:
# np.float64(44.470101841659215)

# %%
exam1_scores.max()
# Out:
# np.float64(92.69754623987608)

# %%
exam2_scores.min()
# Out:
# np.float64(49.10576096502484)

# %%
exam2_scores.max()
# Out:
# np.float64(103.43833764045874)

# %% [markdown]
# adding outlier to dataa

# %%
exam1_scores[0]=120
exam2_scores[1]=30
#Create a scatter plot
plt.figure(figsize=(8,6))
plt.scatter(exam1_scores,exam2_scores)
plt.title('Scatter plot of Exam Scores')
plt.xlabel('Exam1_Scores')
plt.ylabel('Exam2_scores')
plt.grid(True)

# %%
plt.boxplot(exam1_scores)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7d8070f60920>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7d8070f60ec0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7d8070f60110>],
#  'medians': [<matplotlib.lines.Line2D at 0x7d8070f614f0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7d8070f61700>],
#  'means': []}

# %%
plt.boxplot(exam2_scores)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7d8070fcc770>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7d8070fccc20>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7d8070fcc530>],
#  'medians': [<matplotlib.lines.Line2D at 0x7d8070fcd250>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7d8070fcd550>],
#  'means': []}

# %%
data
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# 0             1        337          118                  4  4.5  4.5  9.65
# 1             2        324          107                  4  4.0  4.5  8.87
# 2             3        316          104                  3  3.0  3.5  8.00
# 3             4        322          110                  3  3.5  2.5  8.67
# 4             5        314          103                  2  2.0  3.0  8.21
# ..          ...        ...          ...                ...  ...  ...   ...
# 495         496        332          108                  5  4.5  4.0  9.02
# 496         497        337          117                  5  5.0  5.0  9.87
# 497         498        330          120                  5  4.5  5.0  9.56
# 498         499        312          103                  4  4.0  5.0  8.43
# 499         500        327          113                  4  4.5  4.5  9.04
#
#      Research  Chance of Admit
# 0           1             0.92
# ...

# %%
data.boxplot(column=["Chance of Admit"])
# Out:
# <Axes: >

# %%
data['Chance of Admit'].min()
# Out:
# 0.34

# %%
data.boxplot(column=["GRE Score","TOEFL Score"])
# Out:
# <Axes: >

# %%
data.boxplot(column=["LOR","SOP"])
# Out:
# <Axes: >

# %%
data.boxplot(column=["CGPA","LOR"])
# Out:
# <Axes: >

# %%
data.boxplot(column=["University Rating","SOP","LOR","CGPA","Research"])
# Out:
# <Axes: >

# %%
data1=data.copy()

# %%
data1
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# 0             1        337          118                  4  4.5  4.5  9.65
# 1             2        324          107                  4  4.0  4.5  8.87
# 2             3        316          104                  3  3.0  3.5  8.00
# 3             4        322          110                  3  3.5  2.5  8.67
# 4             5        314          103                  2  2.0  3.0  8.21
# ..          ...        ...          ...                ...  ...  ...   ...
# 495         496        332          108                  5  4.5  4.0  9.02
# 496         497        337          117                  5  5.0  5.0  9.87
# 497         498        330          120                  5  4.5  5.0  9.56
# 498         499        312          103                  4  4.0  5.0  8.43
# 499         500        327          113                  4  4.5  4.5  9.04
#
#      Research  Chance of Admit
# 0           1             0.92
# ...

# %%
data1.drop(["Serial No."],axis=1,inplace=True)

# %%
data1
# Out:
#      GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  Research  \
# 0          337          118                  4  4.5  4.5  9.65         1
# 1          324          107                  4  4.0  4.5  8.87         1
# 2          316          104                  3  3.0  3.5  8.00         1
# 3          322          110                  3  3.5  2.5  8.67         1
# 4          314          103                  2  2.0  3.0  8.21         0
# ..         ...          ...                ...  ...  ...   ...       ...
# 495        332          108                  5  4.5  4.0  9.02         1
# 496        337          117                  5  5.0  5.0  9.87         1
# 497        330          120                  5  4.5  5.0  9.56         1
# 498        312          103                  4  4.0  5.0  8.43         0
# 499        327          113                  4  4.5  4.5  9.04         0
#
#      Chance of Admit
# 0               0.92
# 1               0.76
# 2               0.72
# ...

# %%
data1.head()
# Out:
#    GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  Research  \
# 0        337          118                  4  4.5  4.5  9.65         1
# 1        324          107                  4  4.0  4.5  8.87         1
# 2        316          104                  3  3.0  3.5  8.00         1
# 3        322          110                  3  3.5  2.5  8.67         1
# 4        314          103                  2  2.0  3.0  8.21         0
#
#    Chance of Admit
# 0             0.92
# 1             0.76
# 2             0.72
# 3             0.80
# 4             0.65

# %% [markdown]
# DETECTING THE OUTLIERS

# %%
data1.describe()
# Out:
#         GRE Score  TOEFL Score  University Rating         SOP        LOR  \
# count  500.000000   500.000000         500.000000  500.000000  500.00000
# mean   316.472000   107.192000           3.114000    3.374000    3.48400
# std     11.295148     6.081868           1.143512    0.991004    0.92545
# min    290.000000    92.000000           1.000000    1.000000    1.00000
# 25%    308.000000   103.000000           2.000000    2.500000    3.00000
# 50%    317.000000   107.000000           3.000000    3.500000    3.50000
# 75%    325.000000   112.000000           4.000000    4.000000    4.00000
# max    340.000000   120.000000           5.000000    5.000000    5.00000
#
#              CGPA    Research  Chance of Admit
# count  500.000000  500.000000        500.00000
# mean     8.576440    0.560000          0.72174
# std      0.604813    0.496884          0.14114
# min      6.800000    0.000000          0.34000
# 25%      8.127500    0.000000          0.63000
# ...

# %%
q1=data1.quantile(0.25)
print("q1: ",q1)
q3=data1.quantile(0.75)
print("q3: ",q3)
iqr=q3-q1
# Out:
# q1:  GRE Score            308.0000
# TOEFL Score          103.0000
# University Rating      2.0000
# SOP                    2.5000
# LOR                    3.0000
# CGPA                   8.1275
# Research               0.0000
# Chance of Admit        0.6300
# Name: 0.25, dtype: float64
# q3:  GRE Score            325.00
# TOEFL Score          112.00
# University Rating      4.00
# SOP                    4.00
# LOR                    4.00
# CGPA                   9.04
# Research               1.00
# Chance of Admit        0.82
# Name: 0.75, dtype: float64

# %%
iqr
# Out:
# GRE Score            17.0000
# TOEFL Score           9.0000
# University Rating     2.0000
# SOP                   1.5000
# LOR                   1.0000
# CGPA                  0.9125
# Research              1.0000
# Chance of Admit       0.1900
# dtype: float64

# %%
data1<(q1-1.5*iqr)
# Out:
#      GRE Score  TOEFL Score  University Rating    SOP    LOR   CGPA  Research  \
# 0        False        False              False  False  False  False     False
# 1        False        False              False  False  False  False     False
# 2        False        False              False  False  False  False     False
# 3        False        False              False  False  False  False     False
# 4        False        False              False  False  False  False     False
# ..         ...          ...                ...    ...    ...    ...       ...
# 495      False        False              False  False  False  False     False
# 496      False        False              False  False  False  False     False
# 497      False        False              False  False  False  False     False
# 498      False        False              False  False  False  False     False
# 499      False        False              False  False  False  False     False
#
#      Chance of Admit
# ...

# %%
data1>(q3+1.5*iqr)
# Out:
#      GRE Score  TOEFL Score  University Rating    SOP    LOR   CGPA  Research  \
# 0        False        False              False  False  False  False     False
# 1        False        False              False  False  False  False     False
# 2        False        False              False  False  False  False     False
# 3        False        False              False  False  False  False     False
# 4        False        False              False  False  False  False     False
# ..         ...          ...                ...    ...    ...    ...       ...
# 495      False        False              False  False  False  False     False
# 496      False        False              False  False  False  False     False
# 497      False        False              False  False  False  False     False
# 498      False        False              False  False  False  False     False
# 499      False        False              False  False  False  False     False
#
#      Chance of Admit
# ...

# %%
((data1<(q1-1.5*iqr))|(data1>(q3+1.5*iqr))).any(axis=1)
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 495    False
# 496    False
# 497    False
# 498    False
# 499    False
# Length: 500, dtype: bool

# %%
data1_out=data1[((data1<(q1-1.5*iqr))|(data1>(q3+1.5*iqr))).any(axis=1)]

# %%
print(data1_out.head())
# Out:
#      GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  Research  \
# 92         298           98                  2  4.0  3.0  8.03         0
# 347        299           94                  1  1.0  1.0  7.34         0
# 376        297           96                  2  2.5  2.0  7.43         0
#
#      Chance of Admit
# 92              0.34
# 347             0.42
# 376             0.34

# %%
~((data1<(q1-1.5*iqr))|(data1>(q3+1.5*iqr))).any(axis=1)
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 495    True
# 496    True
# 497    True
# 498    True
# 499    True
# Length: 500, dtype: bool

# %%
data_out=data1[~((data1<(q1-1.5*iqr))|(data1>(q3+1.5*iqr))).any(axis=1)]
data=data_out.copy()

# %%
data
# Out:
#      GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  Research  \
# 0          337          118                  4  4.5  4.5  9.65         1
# 1          324          107                  4  4.0  4.5  8.87         1
# 2          316          104                  3  3.0  3.5  8.00         1
# 3          322          110                  3  3.5  2.5  8.67         1
# 4          314          103                  2  2.0  3.0  8.21         0
# ..         ...          ...                ...  ...  ...   ...       ...
# 495        332          108                  5  4.5  4.0  9.02         1
# 496        337          117                  5  5.0  5.0  9.87         1
# 497        330          120                  5  4.5  5.0  9.56         1
# 498        312          103                  4  4.0  5.0  8.43         0
# 499        327          113                  4  4.5  4.5  9.04         0
#
#      Chance of Admit
# 0               0.92
# 1               0.76
# 2               0.72
# ...

# %%
data.shape
# Out:
# (497, 8)

# %% [markdown]
# UNIVARIATE ANALYSIS

# %%
data["Chance of Admit"]
# Out:
# 0      0.92
# 1      0.76
# 2      0.72
# 3      0.80
# 4      0.65
#        ...
# 495    0.87
# 496    0.96
# 497    0.93
# 498    0.73
# 499    0.84
# Name: Chance of Admit, Length: 497, dtype: float64

# %%
plt.hist(data["Chance of Admit"])
# Out:
# (array([ 9., 20., 29., 36., 70., 85., 77., 62., 48., 61.]),
#  array([0.36 , 0.421, 0.482, 0.543, 0.604, 0.665, 0.726, 0.787, 0.848,
#         0.909, 0.97 ]),
#  <BarContainer object of 10 artists>)

# %%
data["Chance of Admit"].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
data["GRE Score"].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# BIVARIATE ANALYSIS-draw graph between 2 variables

# %%
plt.scatter([1,2,3,4,5],[10,20,30,40,50],c='r')

# %%
data.plot.scatter("GRE Score","Chance of Admit")
# Out:
# <Axes: xlabel='GRE Score', ylabel='Chance of Admit'>

# %%
data.plot.scatter("TOEFL Score","Chance of Admit")
# Out:
# <Axes: xlabel='TOEFL Score', ylabel='Chance of Admit'>

# %%
x=[1,2,3,4,5]
y=[2,4,6,8,10]
mean_x=sum(x)/len(x)
mean_y=sum(y)/len(y)
numerator=sum((xi-mean_x)*(yi-mean_y) for xi,yi in zip(x,y))
denominator_x=sum((xi-mean_x)**2 for xi in x)
denominator_y=sum((yi-mean_y)**2 for yi in y)
correlation_coefficient=numerator/((denominator_x*denominator_y)**0.5)
print("Correlation coefficient between 'x' and 'y':",correlation_coefficient)
# Out:
# Correlation coefficient between 'x' and 'y': 1.0

# %%
data["GRE Score"].corr(data["Chance of Admit"])
# Out:
# np.float64(0.80759358658696)

# %%
data["GRE Score"].corr(data["Chance of Admit"])
# Out:
# np.float64(0.80759358658696)

# %%
data["TOEFL Score"].corr(data["Chance of Admit"])
# Out:
# np.float64(0.7881282679383222)

# %%
data["TOEFL Score"].corr(data["CGPA"])
# Out:
# np.float64(0.8072817048403574)

# %%
data["CGPA"].corr(data["Chance of Admit"])
# Out:
# np.float64(0.8831214773197416)

# %%
data
# Out:
#      GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  Research  \
# 0          337          118                  4  4.5  4.5  9.65         1
# 1          324          107                  4  4.0  4.5  8.87         1
# 2          316          104                  3  3.0  3.5  8.00         1
# 3          322          110                  3  3.5  2.5  8.67         1
# 4          314          103                  2  2.0  3.0  8.21         0
# ..         ...          ...                ...  ...  ...   ...       ...
# 495        332          108                  5  4.5  4.0  9.02         1
# 496        337          117                  5  5.0  5.0  9.87         1
# 497        330          120                  5  4.5  5.0  9.56         1
# 498        312          103                  4  4.0  5.0  8.43         0
# 499        327          113                  4  4.5  4.5  9.04         0
#
#      Chance of Admit
# 0               0.92
# 1               0.76
# 2               0.72
# ...

# %%
c=data.corr()
type(c)
# Out:
# pandas.core.frame.DataFrame

# %%
c
# Out:
#                    GRE Score  TOEFL Score  University Rating       SOP  \
# GRE Score           1.000000     0.824360           0.631514  0.614286
# TOEFL Score         0.824360     1.000000           0.645349  0.643806
# University Rating   0.631514     0.645349           1.000000  0.727569
# SOP                 0.614286     0.643806           0.727569  1.000000
# LOR                 0.518457     0.533263           0.603831  0.659858
# CGPA                0.823739     0.807282           0.701979  0.711175
# Research            0.558932     0.461071           0.422304  0.406490
# Chance of Admit     0.807594     0.788128           0.688621  0.690654
#
#                         LOR      CGPA  Research  Chance of Admit
# GRE Score          0.518457  0.823739  0.558932         0.807594
# TOEFL Score        0.533263  0.807282  0.461071         0.788128
# University Rating  0.603831  0.701979  0.422304         0.688621
# SOP                0.659858  0.711175  0.406490         0.690654
# ...

# %%
import seaborn as sns
correlation_matrix=data.corr()
print(correlation_matrix)
plt.figure(figsize=(8,6))
sns.heatmap(correlation_matrix,annot=True,cmap='coolwarm',fmt=".2f",square=True)
plt.title('Correlation Plot')
plt.show()
# Out:
#                    GRE Score  TOEFL Score  University Rating       SOP  \
# GRE Score           1.000000     0.824360           0.631514  0.614286
# TOEFL Score         0.824360     1.000000           0.645349  0.643806
# University Rating   0.631514     0.645349           1.000000  0.727569
# SOP                 0.614286     0.643806           0.727569  1.000000
# LOR                 0.518457     0.533263           0.603831  0.659858
# CGPA                0.823739     0.807282           0.701979  0.711175
# Research            0.558932     0.461071           0.422304  0.406490
# Chance of Admit     0.807594     0.788128           0.688621  0.690654
#
#                         LOR      CGPA  Research  Chance of Admit
# GRE Score          0.518457  0.823739  0.558932         0.807594
# TOEFL Score        0.533263  0.807282  0.461071         0.788128
# University Rating  0.603831  0.701979  0.422304         0.688621
# SOP                0.659858  0.711175  0.406490         0.690654
# ...

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   GRE Score          500 non-null    int64
#  1   TOEFL Score        500 non-null    int64
#  2   University Rating  500 non-null    int64
#  3   SOP                500 non-null    float64
#  4   LOR                500 non-null    float64
#  5   CGPA               500 non-null    float64
#  6   Research           500 non-null    int64
#  7   Chance of Admit    500 non-null    float64
# dtypes: float64(4), int64(4)
# memory usage: 31.4 KB

# %%
data
# Out:
#      GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  Research  \
# 0          337          118                  4  4.5  4.5  9.65         1
# 1          324          107                  4  4.0  4.5  8.87         1
# 2          316          104                  3  3.0  3.5  8.00         1
# 3          322          110                  3  3.5  2.5  8.67         1
# 4          314          103                  2  2.0  3.0  8.21         0
# ..         ...          ...                ...  ...  ...   ...       ...
# 495        332          108                  5  4.5  4.0  9.02         1
# 496        337          117                  5  5.0  5.0  9.87         1
# 497        330          120                  5  4.5  5.0  9.56         1
# 498        312          103                  4  4.0  5.0  8.43         0
# 499        327          113                  4  4.5  4.5  9.04         0
#
#      Chance of Admit
# 0               0.92
# 1               0.76
# 2               0.72
# ...

# %%
x=data.drop(["Chance of Admit"],axis=1)

# %%
data
# Out:
#      GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  Research  \
# 0          337          118                  4  4.5  4.5  9.65         1
# 1          324          107                  4  4.0  4.5  8.87         1
# 2          316          104                  3  3.0  3.5  8.00         1
# 3          322          110                  3  3.5  2.5  8.67         1
# 4          314          103                  2  2.0  3.0  8.21         0
# ..         ...          ...                ...  ...  ...   ...       ...
# 495        332          108                  5  4.5  4.0  9.02         1
# 496        337          117                  5  5.0  5.0  9.87         1
# 497        330          120                  5  4.5  5.0  9.56         1
# 498        312          103                  4  4.0  5.0  8.43         0
# 499        327          113                  4  4.5  4.5  9.04         0
#
#      Chance of Admit
# 0               0.92
# 1               0.76
# 2               0.72
# ...

# %%
x.head()
# Out:
#    GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  Research
# 0        337          118                  4  4.5  4.5  9.65         1
# 1        324          107                  4  4.0  4.5  8.87         1
# 2        316          104                  3  3.0  3.5  8.00         1
# 3        322          110                  3  3.5  2.5  8.67         1
# 4        314          103                  2  2.0  3.0  8.21         0

# %%
y=data["Chance of Admit"]

# %%
y
# Out:
# 0      0.92
# 1      0.76
# 2      0.72
# 3      0.80
# 4      0.65
#        ...
# 495    0.87
# 496    0.96
# 497    0.93
# 498    0.73
# 499    0.84
# Name: Chance of Admit, Length: 497, dtype: float64

# %%
data["GRE Score"]
# Out:
# 0      337
# 1      324
# 2      316
# 3      322
# 4      314
#       ...
# 495    332
# 496    337
# 497    330
# 498    312
# 499    327
# Name: GRE Score, Length: 497, dtype: int64

# %%
xgre=data["GRE Score"]

# %%
xgre=data["GRE Score"]

# %%
x.shape
# Out:
# (497, 7)

# %%
xgre.shape
# Out:
# (497,)

# %%
xgre.ndim
# Out:
# 1

# %%
xgre
# Out:
# 0      337
# 1      324
# 2      316
# 3      322
# 4      314
#       ...
# 495    332
# 496    337
# 497    330
# 498    312
# 499    327
# Name: GRE Score, Length: 497, dtype: int64

# %%
xgre.values
# Out:
# array([337, 324, 316, 322, 314, 330, 321, 308, 302, 323, 325, 327, 328,
#        307, 311, 314, 317, 319, 318, 303, 312, 325, 328, 334, 336, 340,
#        322, 298, 295, 310, 300, 327, 338, 340, 331, 320, 299, 300, 304,
#        307, 308, 316, 313, 332, 326, 322, 329, 339, 321, 327, 313, 312,
#        334, 324, 322, 320, 316, 298, 300, 311, 309, 307, 304, 315, 325,
#        325, 327, 316, 318, 328, 332, 336, 321, 314, 314, 329, 327, 301,
#        296, 294, 312, 340, 320, 322, 340, 319, 315, 317, 314, 316, 318,
#        299, 301, 303, 304, 306, 331, 332, 323, 322, 312, 314, 317, 326,
#        316, 329, 338, 331, 304, 305, 321, 301, 320, 311, 310, 299, 290,
#        296, 327, 335, 334, 310, 308, 301, 300, 323, 319, 326, 333, 339,
#        303, 309, 323, 333, 314, 312, 316, 326, 318, 329, 332, 331, 340,
#        325, 320, 315, 326, 339, 311, 334, 332, 321, 324, 326, 312, 315,
#        309, 306, 297, 315, 298, 318, 317, 329, 322, 302, 313, 293, 311,
# ...

# %%
xarr=xgre.values

# %%
xarr
# Out:
# array([337, 324, 316, 322, 314, 330, 321, 308, 302, 323, 325, 327, 328,
#        307, 311, 314, 317, 319, 318, 303, 312, 325, 328, 334, 336, 340,
#        322, 298, 295, 310, 300, 327, 338, 340, 331, 320, 299, 300, 304,
#        307, 308, 316, 313, 332, 326, 322, 329, 339, 321, 327, 313, 312,
#        334, 324, 322, 320, 316, 298, 300, 311, 309, 307, 304, 315, 325,
#        325, 327, 316, 318, 328, 332, 336, 321, 314, 314, 329, 327, 301,
#        296, 294, 312, 340, 320, 322, 340, 319, 315, 317, 314, 316, 318,
#        299, 301, 303, 304, 306, 331, 332, 323, 322, 312, 314, 317, 326,
#        316, 329, 338, 331, 304, 305, 321, 301, 320, 311, 310, 299, 290,
#        296, 327, 335, 334, 310, 308, 301, 300, 323, 319, 326, 333, 339,
#        303, 309, 323, 333, 314, 312, 316, 326, 318, 329, 332, 331, 340,
#        325, 320, 315, 326, 339, 311, 334, 332, 321, 324, 326, 312, 315,
#        309, 306, 297, 315, 298, 318, 317, 329, 322, 302, 313, 293, 311,
# ...

# %%
len(xarr)
# Out:
# 497

# %%
xarr=xarr.reshape((len(xarr),1))

# %%
xarr.shape
# Out:
# (497, 1)

# %%
xarr.ndim
# Out:
# 2

# %%
y
# Out:
# 0      0.92
# 1      0.76
# 2      0.72
# 3      0.80
# 4      0.65
#        ...
# 495    0.87
# 496    0.96
# 497    0.93
# 498    0.73
# 499    0.84
# Name: Chance of Admit, Length: 497, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(xarr,y,random_state=50)

# %%
xarr.shape
# Out:
# (497, 1)

# %%
y.shape
# Out:
# (497,)

# %%
x_train.shape
# Out:
# (372, 1)

# %%
y_train.shape
# Out:
# (372,)

# %%
x_test.shape
# Out:
# (125, 1)

# %%
y_test.shape
# Out:
# (125,)

# %%
from sklearn.linear_model import LinearRegression as LR
from sklearn.metrics import mean_absolute_error as MAE

# %%
slr=LR()

# %%
dir(slr)
# Out:
# ['__abstractmethods__',
#  '__annotations__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__sklearn_clone__',
#  '__sklearn_tags__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_abc_impl',
#  '_build_request_for_signature',
#  '_check_feature_names',
#  '_check_n_features',
#  '_decision_function',
#  '_doc_link_module',
#  '_doc_link_template',
#  '_doc_link_url_param_generator',
#  '_estimator_type',
#  '_get_default_requests',
#  '_get_doc_link',
#  '_get_metadata_request',
#  '_get_param_names',
#  '_get_tags',
#  '_more_tags',
#  '_parameter_constraints',
#  '_repr_html_',
#  '_repr_html_inner',
# ...

# %%
slr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
print(slr.coef_)
# Out:
# [0.00995293]

# %%
print(slr.intercept_)
# Out:
# -2.429543329482838

# %%
m=slr.coef_[0]

# %%
m
# Out:
# np.float64(0.00995293018877281)

# %%
c=slr.intercept_

# %%
data.head()
# Out:
#    GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  Research  \
# 0        337          118                  4  4.5  4.5  9.65         1
# 1        324          107                  4  4.0  4.5  8.87         1
# 2        316          104                  3  3.0  3.5  8.00         1
# 3        322          110                  3  3.5  2.5  8.67         1
# 4        314          103                  2  2.0  3.0  8.21         0
#
#    Chance of Admit
# 0             0.92
# 1             0.76
# 2             0.72
# 3             0.80
# 4             0.65

# %%
ca=m*337+c

# %%
print(ca)
# Out:
# 0.9245941441335987

# %%
xarr
# Out:
# array([[337],
#        [324],
#        [316],
#        [322],
#        [314],
#        [330],
#        [321],
#        [308],
#        [302],
#        [323],
#        [325],
#        [327],
#        [328],
#        [307],
#        [311],
#        [314],
#        [317],
#        [319],
#        [318],
#        [303],
#        [312],
#        [325],
#        [328],
#        [334],
#        [336],
#        [340],
#        [322],
#        [298],
#        [295],
#        [310],
#        [300],
#        [327],
#        [338],
#        [340],
#        [331],
#        [320],
#        [299],
#        [300],
#        [304],
#        [307],
#        [308],
#        [316],
#        [313],
#        [332],
#        [326],
#        [322],
#        [329],
#        [339],
#        [321],
#        [327],
#        [313],
#        [312],
#        [334],
#        [324],
#        [322],
#        [320],
#        [316],
#        [298],
#        [300],
#        [311],
#        [309],
#        [307],
# ...

# %%
m*xarr+c
# Out:
# array([[0.92459414],
#        [0.79520605],
#        [0.71558261],
#        [0.77530019],
#        [0.69567675],
#        [0.85492363],
#        [0.76534726],
#        [0.63595917],
#        [0.57624159],
#        [0.78525312],
#        [0.80515898],
#        [0.82506484],
#        [0.83501777],
#        [0.62600624],
#        [0.66581796],
#        [0.69567675],
#        [0.72553554],
#        [0.7454414 ],
#        [0.73548847],
#        [0.58619452],
#        [0.67577089],
#        [0.80515898],
#        [0.83501777],
#        [0.89473535],
#        [0.91464121],
#        [0.95445293],
#        [0.77530019],
#        [0.53642987],
#        [0.50657108],
#        [0.65586503],
#        [0.55633573],
#        [0.82506484],
#        [0.93454707],
#        [0.95445293],
#        [0.86487656],
#        [0.75539433],
#        [0.5463828 ],
#        [0.55633573],
#        [0.59614745],
#        [0.62600624],
#        [0.63595917],
#        [0.71558261],
#        [0.68572382],
# ...

# %%
list(zip(y,m*xarr+c))
# Out:
# [(0.92, array([0.92459414])),
#  (0.76, array([0.79520605])),
#  (0.72, array([0.71558261])),
#  (0.8, array([0.77530019])),
#  (0.65, array([0.69567675])),
#  (0.9, array([0.85492363])),
#  (0.75, array([0.76534726])),
#  (0.68, array([0.63595917])),
#  (0.5, array([0.57624159])),
#  (0.45, array([0.78525312])),
#  (0.52, array([0.80515898])),
#  (0.84, array([0.82506484])),
#  (0.78, array([0.83501777])),
#  (0.62, array([0.62600624])),
#  (0.61, array([0.66581796])),
#  (0.54, array([0.69567675])),
#  (0.66, array([0.72553554])),
#  (0.65, array([0.7454414])),
#  (0.63, array([0.73548847])),
#  (0.62, array([0.58619452])),
#  (0.64, array([0.67577089])),
#  (0.7, array([0.80515898])),
#  (0.94, array([0.83501777])),
#  (0.95, array([0.89473535])),
#  (0.97, array([0.91464121])),
#  (0.94, array([0.95445293])),
#  (0.76, array([0.77530019])),
#  (0.44, array([0.53642987])),
#  (0.46, array([0.50657108])),
#  (0.54, array([0.65586503])),
#  (0.65, array([0.55633573])),
# ...

# %%
plt.scatter(xarr,y)
plt.grid()

# %%
plt.scatter(xarr,y)
plt.plot(xarr,m*xarr+c,color='red')

# %%
ca=m*337+c

# %%
ca
# Out:
# np.float64(0.9245941441335987)

# %%
slr.predict([[337]])
# Out:
# array([0.92459414])

# %%
greScore=int(input("Enter GRE Score: "))
ca=slr.predict([[greScore]])
print("Chance of Admit: ",ca[0])
# Out:
# Enter GRE Score: 332
# Chance of Admit:  0.8748294931897349

# %%
x_test
# Out:
# array([[308],
#        [314],
#        [312],
#        [310],
#        [313],
#        [320],
#        [321],
#        [322],
#        [328],
#        [298],
#        [329],
#        [319],
#        [320],
#        [332],
#        [315],
#        [332],
#        [327],
#        [324],
#        [294],
#        [297],
#        [311],
#        [334],
#        [311],
#        [310],
#        [317],
#        [307],
#        [332],
#        [334],
#        [319],
#        [321],
#        [324],
#        [313],
#        [310],
#        [295],
#        [331],
#        [315],
#        [313],
#        [316],
#        [299],
#        [305],
#        [310],
#        [332],
#        [327],
#        [304],
#        [299],
#        [323],
#        [324],
#        [330],
#        [323],
#        [327],
#        [300],
#        [315],
#        [333],
#        [326],
#        [317],
#        [336],
#        [332],
#        [311],
#        [306],
#        [324],
#        [317],
#        [328],
# ...

# %%
y_test
# Out:
# 223    0.71
# 88     0.64
# 334    0.73
# 122    0.57
# 42     0.53
#        ...
# 426    0.71
# 456    0.51
# 1      0.76
# 228    0.71
# 117    0.45
# Name: Chance of Admit, Length: 125, dtype: float64

# %%
x
# Out:
#      GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  Research
# 0          337          118                  4  4.5  4.5  9.65         1
# 1          324          107                  4  4.0  4.5  8.87         1
# 2          316          104                  3  3.0  3.5  8.00         1
# 3          322          110                  3  3.5  2.5  8.67         1
# 4          314          103                  2  2.0  3.0  8.21         0
# ..         ...          ...                ...  ...  ...   ...       ...
# 495        332          108                  5  4.5  4.0  9.02         1
# 496        337          117                  5  5.0  5.0  9.87         1
# 497        330          120                  5  4.5  5.0  9.56         1
# 498        312          103                  4  4.0  5.0  8.43         0
# 499        327          113                  4  4.5  4.5  9.04         0
#
# [497 rows x 7 columns]

# %% [markdown]
# MULTIPLE LINEAR REGRESSION

# %%
train_x,test_x,train_y,test_y=train_test_split(x,y,random_state=56)

# %%
x_train.shape
# Out:
# (372,)

# %%
y_train.shape
# Out:
# (125,)

# %%
x_test.shape
# Out:
# (372, 7)

# %%
y_test.shape
# Out:
# (125, 7)

# %%
x
# Out:
#      GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  Research
# 0          337          118                  4  4.5  4.5  9.65         1
# 1          324          107                  4  4.0  4.5  8.87         1
# 2          316          104                  3  3.0  3.5  8.00         1
# 3          322          110                  3  3.5  2.5  8.67         1
# 4          314          103                  2  2.0  3.0  8.21         0
# ..         ...          ...                ...  ...  ...   ...       ...
# 495        332          108                  5  4.5  4.0  9.02         1
# 496        337          117                  5  5.0  5.0  9.87         1
# 497        330          120                  5  4.5  5.0  9.56         1
# 498        312          103                  4  4.0  5.0  8.43         0
# 499        327          113                  4  4.5  4.5  9.04         0
#
# [497 rows x 7 columns]

# %%
y
# Out:
# 0      0.92
# 1      0.76
# 2      0.72
# 3      0.80
# 4      0.65
#        ...
# 495    0.87
# 496    0.96
# 497    0.93
# 498    0.73
# 499    0.84
# Name: Chance of Admit, Length: 497, dtype: float64

# %%
mlr=LR()

# %%
mlr
# Out:
# LinearRegression()

# %%
mlr.fit(train_x,train_y)
# Out:
# LinearRegression()

# %%
train_x.head()
# Out:
#      GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  Research
# 261        312          104                  3  3.5  4.0  8.09         0
# 367        311           98                  1  1.0  2.5  7.46         0
# 21         325          114                  4  3.0  2.0  8.40         0
# 326        299          100                  3  2.0  2.0  8.02         0
# 126        323          113                  3  4.0  3.0  9.32         1

# %%
mlr.coef_
# Out:
# array([0.00198744, 0.00243068, 0.00307841, 0.00793898, 0.01730829,
#        0.11125989, 0.02276153])

# %%
mlr.intercept_
# Out:
# np.float64(-1.2273935762913175)

# %%
data
# Out:
#      GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  Research  \
# 0          337          118                  4  4.5  4.5  9.65         1
# 1          324          107                  4  4.0  4.5  8.87         1
# 2          316          104                  3  3.0  3.5  8.00         1
# 3          322          110                  3  3.5  2.5  8.67         1
# 4          314          103                  2  2.0  3.0  8.21         0
# ..         ...          ...                ...  ...  ...   ...       ...
# 495        332          108                  5  4.5  4.0  9.02         1
# 496        337          117                  5  5.0  5.0  9.87         1
# 497        330          120                  5  4.5  5.0  9.56         1
# 498        312          103                  4  4.0  5.0  8.43         0
# 499        327          113                  4  4.5  4.5  9.04         0
#
#      Chance of Admit
# 0               0.92
# 1               0.76
# 2               0.72
# ...

# %%
mlr.predict([[327,113,4,4.5,4.5,9.04,0]])
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([0.82888232])

# %%
data.head(3)
# Out:
#    GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  Research  \
# 0        337          118                  4  4.5  4.5  9.65         1
# 1        324          107                  4  4.0  4.5  8.87         1
# 2        316          104                  3  3.0  3.5  8.00         1
#
#    Chance of Admit
# 0             0.92
# 1             0.76
# 2             0.72

# %%
x_test
# Out:
#      GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  Research
# 223        308          109                  2  3.0  4.0  8.45         0
# 88         314          108                  3  4.5  3.5  8.14         0
# 334        312          107                  4  4.5  4.0  8.65         1
# 122        310          106                  4  1.5  2.5  8.36         0
# 42         313          107                  2  2.5  2.0  8.50         1
# ..         ...          ...                ...  ...  ...   ...       ...
# 426        312          106                  3  3.0  5.0  8.57         0
# 456        299          100                  2  2.0  2.0  7.88         0
# 1          324          107                  4  4.0  4.5  8.87         1
# 228        318          112                  3  4.0  3.5  8.67         0
# 117        290          104                  4  2.0  2.5  7.46         0
#
# [125 rows x 7 columns]

# %%
x_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 125 entries, 223 to 117
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   GRE Score          125 non-null    int64
#  1   TOEFL Score        125 non-null    int64
#  2   University Rating  125 non-null    int64
#  3   SOP                125 non-null    float64
#  4   LOR                125 non-null    float64
#  5   CGPA               125 non-null    float64
#  6   Research           125 non-null    int64
# dtypes: float64(3), int64(4)
# memory usage: 7.8 KB

# %%
y_test
# Out:
# 223    0.71
# 88     0.64
# 334    0.73
# 122    0.57
# 42     0.53
#        ...
# 426    0.71
# 456    0.51
# 1      0.76
# 228    0.71
# 117    0.45
# Name: Chance of Admit, Length: 125, dtype: float64

# %%
y_test.info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 125 entries, 223 to 117
# Series name: Chance of Admit
# Non-Null Count  Dtype
# --------------  -----
# 125 non-null    float64
# dtypes: float64(1)
# memory usage: 2.0 KB

# %%
test_predict=mlr.predict(x_test)

# %%
test_predict
# Out:
# array([0.68903544, 0.67037158, 0.75520264, 0.64399081, 0.68384974,
#        0.81542691, 0.83297379, 0.777907  , 0.85278058, 0.50241177,
#        0.88647094, 0.75267422, 0.72695632, 0.757857  , 0.6657396 ,
#        0.8858725 , 0.77238526, 0.79193289, 0.47880363, 0.53237561,
#        0.67598907, 0.96061944, 0.6668711 , 0.62512974, 0.60974296,
#        0.70408221, 0.84162672, 0.98267946, 0.73437077, 0.65768852,
#        0.86904609, 0.63976225, 0.65796324, 0.52860621, 0.9494835 ,
#        0.69865043, 0.72878393, 0.73928986, 0.57720007, 0.63774723,
#        0.80084258, 0.9023866 , 0.83836259, 0.51527196, 0.67541114,
#        0.74626697, 0.87680916, 0.87921041, 0.86086396, 0.82827654,
#        0.54506536, 0.63690813, 0.96753279, 0.81692149, 0.70890268,
#        0.95047304, 0.93727825, 0.67355853, 0.63351372, 0.84197392,
#        0.72358513, 0.78500504, 0.67345163, 0.55574097, 0.77496842,
#        0.5906102 , 0.89474004, 0.69146073, 0.8485382 , 0.79839422,
# ...

# %%
list(zip(test_predict,y_test))
# Out:
# [(np.float64(0.6890354408770345), 0.71),
#  (np.float64(0.6703715820064218), 0.64),
#  (np.float64(0.7552026412244068), 0.73),
#  (np.float64(0.6439908071329508), 0.57),
#  (np.float64(0.6838497383791042), 0.53),
#  (np.float64(0.8154269124542495), 0.84),
#  (np.float64(0.8329737930943386), 0.85),
#  (np.float64(0.7779070007235944), 0.78),
#  (np.float64(0.8527805780592619), 0.82),
#  (np.float64(0.5024117670527612), 0.53),
#  (np.float64(0.8864709415530396), 0.86),
#  (np.float64(0.752674223763864), 0.73),
#  (np.float64(0.7269563187274863), 0.74),
#  (np.float64(0.757857002190661), 0.79),
#  (np.float64(0.6657396011697141), 0.75),
#  (np.float64(0.885872504043494), 0.9),
#  (np.float64(0.7723852595025618), 0.8),
#  (np.float64(0.7919328883434766), 0.8),
#  (np.float64(0.47880362832395074), 0.49),
#  (np.float64(0.5323756139057108), 0.59),
#  (np.float64(0.675989073366035), 0.79),
#  (np.float64(0.9606194376941466), 0.95),
#  (np.float64(0.6668711018389373), 0.71),
# ...

# %%
abs(-100)
# Out:
# 100

# %%
test_predict-y_test
# Out:
# 223   -0.020965
# 88     0.030372
# 334    0.025203
# 122    0.073991
# 42     0.153850
#          ...
# 426    0.013431
# 456    0.033299
# 1      0.048214
# 228    0.033042
# 117    0.053216
# Name: Chance of Admit, Length: 125, dtype: float64

# %%
abs=(test_predict-y_test).mean()

# %%
k=MAE(y_test,test_predict)

# %%
k
# Out:
# 0.03810008286250599

# %% [markdown]
# MEAN SQUARED ERROR

# %%
from sklearn.metrics import mean_squared_error,r2_score

# %%
mse=mean_squared_error(y_test,test_predict)
print("Mean Squared Error: ",mse)
# Out:
# Mean Squared Error:  0.002914475554960452

# %%
rmse=np.sqrt(mse)
print("Root Mean Squared Error: ",rmse)
# Out:
# Root Mean Squared Error:  0.05398588292285727

# %%
r_squared=r2_score(y_test,test_predict)
print("R-Squared: ",r_squared)
# Out:
# R-Squared:  0.8427477449281499

# %%
residuals=y_test-test_predict
sns.scatterplot(x=y_test,y=residuals)
plt.axhline(y=0,color='r',linestyle='--')
plt.xlabel("Predicted Values")
plt.ylabel("Residuals")
plt.title("Residual Plot")
plt.show()

# %%
import matplotlib.pyplot as plt
plt.scatter(y_test,test_predict,color='blue',label='Actual vs. Predicted')
plt.plot(y_test,y_test,color='red',linestyle='--',label='Ideal Line')
plt.xlabel("Actual Values")
plt.ylabel("Predicted Values")
plt.title("Actual vs. Predicted Values")
plt.legend()
plt.show()
