# %% [markdown]
# <a href="https://colab.research.google.com/github/Priya4740/machine-learning/blob/main/titanic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
from sklearn.preprocessing import LabelEncoder

# %%
df=pd.read_csv("https://raw.githubusercontent.com/bapujik/dataSets/refs/heads/main/titanic.csv")

# %%
df
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0           0       3    male  22.0      1      0   7.2500        S
# 1           1       1  female  38.0      1      0  71.2833        C
# 2           1       3  female  26.0      0      0   7.9250        S
# 3           1       1  female  35.0      1      0  53.1000        S
# 4           0       3    male  35.0      0      0   8.0500        S
# ..        ...     ...     ...   ...    ...    ...      ...      ...
# 886         0       2    male  27.0      0      0  13.0000        S
# 887         1       1  female  19.0      0      0  30.0000        S
# 888         0       3  female  17.0      1      2  23.4500        S
# 889         1       1    male  26.0      0      0  30.0000        C
# 890         0       3    male  32.0      0      0   7.7500        Q
#
# [891 rows x 8 columns]

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df['Age'],df['Embarked'])

# %%
encoder=LabelEncoder()
df['Sex']=encoder.fit_transform(df['Sex'])
df['Embarked']=encoder.fit_transform(df['Embarked'])
df
# Out:
#      Survived  Pclass  Sex   Age  SibSp  Parch     Fare  Embarked
# 0           0       3    1  22.0      1      0   7.2500         2
# 1           1       1    0  38.0      1      0  71.2833         0
# 2           1       3    0  26.0      0      0   7.9250         2
# 3           1       1    0  35.0      1      0  53.1000         2
# 4           0       3    1  35.0      0      0   8.0500         2
# ..        ...     ...  ...   ...    ...    ...      ...       ...
# 886         0       2    1  27.0      0      0  13.0000         2
# 887         1       1    0  19.0      0      0  30.0000         2
# 888         0       3    0  17.0      1      2  23.4500         2
# 889         1       1    1  26.0      0      0  30.0000         0
# 890         0       3    1  32.0      0      0   7.7500         1
#
# [891 rows x 8 columns]

# %%
plt.scatter(df['Fare'],df['Embarked'])

# %%
import seaborn as sns

# %%
sns.pairplot(df)

# %%
sns.pairplot(df,hue='Embarked')

# %%
sns.pairplot(df,hue='Embarked',palette="dark")

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
x=df.drop('Survived',axis=1)

# %%
x
# Out:
#      Pclass  Sex   Age  SibSp  Parch     Fare  Embarked
# 0         3    1  22.0      1      0   7.2500         2
# 1         1    0  38.0      1      0  71.2833         0
# 2         3    0  26.0      0      0   7.9250         2
# 3         1    0  35.0      1      0  53.1000         2
# 4         3    1  35.0      0      0   8.0500         2
# ..      ...  ...   ...    ...    ...      ...       ...
# 886       2    1  27.0      0      0  13.0000         2
# 887       1    0  19.0      0      0  30.0000         2
# 888       3    0  17.0      1      2  23.4500         2
# 889       1    1  26.0      0      0  30.0000         0
# 890       3    1  32.0      0      0   7.7500         1
#
# [891 rows x 7 columns]

# %%
y=df['Survived']
y
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=45)

# %%
model=LogisticRegression(max_iter=3000)

# %%
model.fit(x_train,y_train)
# Out:
# LogisticRegression(max_iter=3000)

# %%
predictions=model.predict(x_test)
print(predictions)
# Out:
# [2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2
#  0 2 2 2 2 2 2 2 2 2 2 0 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2
#  2 2 2 2 2 2 2 2 2 2 2 0 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2
#  2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 0 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 0
#  2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 0 2 2 2 2 2]

# %%
from sklearn.metrics import accuracy_score
accuracy=accuracy_score(y_test,predictions)
print("Accuracy",accuracy)
# Out:
# Accuracy 0.7318435754189944

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix=confusion_matrix(y_test,predictions)
print(confusion_matrix)
# Out:
# [[  4   0  28]
#  [  0   0  18]
#  [  2   0 127]]

# %%
sns.heatmap(confusion_matrix,annot=True)
# Out:
# <Axes: >

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.67      0.12      0.21        32
#            1       0.00      0.00      0.00        18
#            2       0.73      0.98      0.84       129
#
#     accuracy                           0.73       179
#    macro avg       0.47      0.37      0.35       179
# weighted avg       0.65      0.73      0.64       179
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...
